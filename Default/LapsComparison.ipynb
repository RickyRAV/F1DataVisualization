# %%
import fastf1 as ff1
import fastf1.plotting as ff1pl
import matplotlib.pyplot as plt

# %%
ff1.Cache.enable_cache('cache')

# %%
ff1.plotting.setup_mpl()

# %%
year, event, event_type = 2023, 'Bahrain Grand Prix', 'R'
session = ff1.get_session(year, event, event_type)
session.load()
# Out:
# core           INFO 	Loading data for Bahrain Grand Prix - Race [v2.3.0]
# api            INFO 	Using cached data for driver_info
# api            INFO 	Using cached data for timing_data
# api            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# api            INFO 	Using cached data for session_status_data
# api            INFO 	Using cached data for track_status_data
# C:\Users\Ricky\AppData\Local\Programs\Python\Python311\Lib\site-packages\fastf1\core.py:1492: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for key, value in row.iteritems():
# C:\Users\Ricky\AppData\Local\Programs\Python\Python311\Lib\site-packages\fastf1\core.py:1415: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df = pd.concat([df, result], sort=False)
# ...

# %%
driver_1, driver_2 = 'VER', 'NOR'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 driver_1, driver_2 = 'HAM', 'VER'
# ----> 2 team_d1 = driver_1['Team']
#       3 team_d2 = driver_2['Team']
#
# TypeError: string indices must be integers, not 'str'

# %%
data_1 = session.laps.pick_driver(driver_1)
data_2 = session.laps.pick_driver(driver_2)
team1_color = ff1pl.team_color(teamd1)
team2_color = ff1pl.team_color(teamd2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 data_1 = session.laps.pick_driver(driver_1)
#       2 data_2 = session.laps.pick_driver(driver_2)
#       3 team1_color = ff1pl.team_color(teamd1)
#
# NameError: name 'driver_1' is not defined

# %%
plt.rcParams['figure.figsize'] = [12,5]
fig, ax = plt.subplots()
ax.plot(data_1['LapNumber'], data_1['LapTime'], color=team1_color, label=driver1)
ax.plot(data_2['LapNumber'], data_2['LapTime'], color=team2_color, label=driver2)
plt.title(f"{session.event['EventName']} {session.event.year} Race\n"
         "LAPS Time Comparison")
ax.set_xlabel("Lap Number")
ax.legend(prop={"size":15})
ax.set_ylabel("Lap Time")
plt.show()
